# %% [markdown]
# <a href="https://colab.research.google.com/github/letter-b/lab-python-list-dict-set-comprehension/blob/main/LAB_lab_python_list_comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab | List, Dict and Set Comprehension

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized with Comprehension

# %% [markdown]
# In the previous exercise, you developed a program to manage customer orders and inventory. Now, let's take it a step further and incorporate comprehension into your code.
#
# Follow the steps below to complete the exercise:
#
# 1. Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.
#
#     - *Hint: Apply it to initialize inventory, updating the inventory and printing the updated inventory.*
#
#     - For example, in initializing the inventory, we could have:
#
#         ```python
#         def initialize_inventory(products):
#             inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
#             return inventory
#
#         ```
# <br>
#
#
# 2. Modify the function get_customer_orders so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.
#
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.
#
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.
#
# 5. Print the total price of the customer order.
#
# Your code should produce output similar to the following:
#
# ```python
# Enter the quantity of t-shirts available:  5
# Enter the quantity of mugs available:  4
# Enter the quantity of hats available:  3
# Enter the quantity of books available:  2
# Enter the quantity of keychains available:  1
# Enter the number of customer orders:  2
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  keychain
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Unique Products Ordered: 40.0
#
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 2
# book: 2
# Enter the price of keychain:  5
# Enter the price of hat:  10
# Total Price: 15.0
#
# ```

# %%
#Previous:
def initialize_inventory(products):
    inventory = {}
    for item in products:
        quantity = input(f'Number of {item} available in stock: ')
        while not quantity.isdigit():
            quantity = input(f'Please enter a valid number of {item} available in stock: ')
        inventory[item] = int(quantity)  # Convert the valid quantity to an integer
    return inventory

# %%
#1. Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.
def initialize_inventory(products):
    inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
    return inventory

# %%
#Previous
def get_customer_orders():
    customer_orders = set()
    while True:
        order = input('Enter the name of your product or "done" if you are done ordering: ')
        if order == 'done':
            break
        customer_orders.add(order)
    return customer_orders
    print(customer_orders)  # Placing this print before the return will allow orders to be displayed

# %%
#2. Modify the function get_customer_orders so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.
def get_customer_orders():
    try:
        num_orders = int(input('Enter the number of different products you wish to order: '))
    except ValueError:
        print("Please enter a valid integer for the number of orders.")
        return set()

    # Gather product names using set comprehension
    customer_orders = {input(f'Enter the name of product client wants to order {i + 1}: ') for i in range(num_orders)}

    # Return the set of customer orders
    return customer_orders

# Example usage
orders = get_customer_orders()
print(orders)
# Out:
# Enter the number of different products you wish to order: 4
# Enter the name of product client wants to order 1: hat
# Enter the name of product client wants to order 2: mug
# Enter the name of product client wants to order 3: cup
# Enter the name of product client wants to order 4: book
# {'book', 'mug', 'cup', 'hat'}

# %%
#Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.
def calculate_total_price(customer_orders):
    try:
        total_price = sum(float(input(f"Enter the price of {product}: ")) for product in customer_orders)
    except ValueError:
        print("Please enter a valid number for the price.")
        return None
    return total_price

# Call the function and print the total price
total_price = calculate_total_price(orders)
if total_price is not None:
    print(f"Total price: {total_price}")
# Out:
# Enter the price of book: 17.99
# Enter the price of mug: 12.99
# Enter the price of cup: 8.99
# Enter the price of hat: 11.99
# Total price: 51.96

# %%
#Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.
def update_inventory(customer_orders, inventory):
    # Decrement quantities for ordered items
    for product in customer_orders:
        if product in inventory and inventory[product] > 0:
            inventory[product] -= 1
 # Filter out products with zero or less quantity using comprehension
    inventory = {product: quantity for product, quantity in inventory.items() if quantity > 0}
    return inventory

# Define products list (based on example output or common items)
products = ['t-shirt', 'mug', 'hat', 'book', 'keychain']

# Initialize inventory using the function from a previous cell
inventory = initialize_inventory(products)

# Assuming 'orders' variable is already populated from previous cell execution
# orders = get_customer_orders()

print("Original Inventory:", inventory)

updated_inventory_result = (update_inventory)(orders, inventory)
print("Updated Inventory:", updated_inventory_result)
# Out:
# Enter the quantity of t-shirts available: 10
# Enter the quantity of mugs available: 21
# Enter the quantity of hats available: 8
# Enter the quantity of books available: 17
# Enter the quantity of keychains available: 32
# Original Inventory: {'t-shirt': 10, 'mug': 21, 'hat': 8, 'book': 17, 'keychain': 32}
# Updated Inventory: {'t-shirt': 10, 'mug': 20, 'hat': 7, 'book': 16, 'keychain': 32}

# %%
#5. Print the total price of the customer order.
def calculate_total_price(customer_orders):
  total_price = sum(float(input(f"Enter the price of {product}: ")) for product in customer)
  return total_price

# Call the function and print the total price

print(f"The total price of your order is {total_price}€.")
# Out:
# The total price of your order is 51.96€.
